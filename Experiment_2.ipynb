# %% [markdown]
# <a href="https://colab.research.google.com/github/kanika215/Deep-Learning/blob/main/Experiment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras

celsius = np.array([-40, -10, 0, 8, 15, 22, 38], dtype=float)
fahrenheit = np.array([-40, 14, 32, 46, 59, 72, 100], dtype=float)

model = keras.Sequential([
    keras.Input(shape=(1,)),
    keras.layers.Dense(units=1)
])

model.compile(optimizer=keras.optimizers.Adam(learning_rate=0.1), loss='mean_squared_error')
model.fit(celsius, fahrenheit, epochs=2000, verbose=0)

test_value = np.array([[25.0]])
prediction = model.predict(test_value)

print(f"25°C = {prediction[0][0]:.2f}°F")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 25°C = 76.90°F
